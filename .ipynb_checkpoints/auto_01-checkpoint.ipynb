# %%
import pandas as pd
import numpy as np
import seaborn as sns
import regex
import datetime
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore')

# Show 2 decimals
pd.set_option('display.float_format', lambda x: '%.0f' % x)
#pd.options.display.float_format = '{:,.2f}'.format

#Butun kolon ve satirlari gormek icin
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# Set plot background
sns.set_theme(style="whitegrid")

# Euro sign €
#print ("%s"%(u"\N{euro sign}"))

# %%
auto = pd.read_csv("/Users/macbook/Desktop/csv_dosyalari/autoscout_data_2000.csv")
df = auto.copy()
df.head(5)
# Out:
#             location                                                url  \
# 0   LOON OP ZAND, NL  https://www.autoscout24.com/offers/audi-a3-2-0...
# 1        HEERLEN, NL  https://www.autoscout24.com/offers/audi-a3-spo...
# 2          BREDA, NL  https://www.autoscout24.com/offers/audi-a3-1-4...
# 3  BAARLE-NASSAU, NL  https://www.autoscout24.com/offers/audi-a1-1-4...
# 4        ZUTPHEN, NL  https://www.autoscout24.com/offers/audi-a1-s-l...
#
#           make     model                                  short_description  \
# 0  \n,Audi ,\n  \n,A3,\n                          2.0 FSI Ambition Pro Line
# 1  \n,Audi ,\n  \n,A3,\n  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
# 2  \n,Audi ,\n  \n,A3,\n  1.4 TFSI Attraction Pro Line [ Navi Airco Crui...
# 3  \n,Audi ,\n  \n,A1,\n    1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.
# 4  \n,Audi ,\n  \n,A1,\n  S-Line | Automaat | Navigatie | Cruise-/Climat...
#
#                           price               mileage          gearbox  \
# 0   [['\n', '€ 4,450.-', '\n']]  ['', ['191,066 km']]  \n,Automatic,\n
# 1  [['\n', '€ 12,950.-', '\n']]   ['', ['94,758 km']]  \n,Automatic,\n
# 2  [['\n', '€ 12,445.-', '\n']]  ['', ['160,883 km']]  \n,Automatic,\n
# 3  [['\n', '€ 12,450.-', '\n']]  ['', ['145,102 km']]  \n,Automatic,\n
# 4  [['\n', '€ 14,945.-', '\n']]  ['', ['119,666 km']]  \n,Automatic,\n
#
#   registration       fuel_type             power                seller  \
# 0      08/2003  \n,Gasoline,\n  110 kW (150 hp),  ['\n', ['Dealer\n']]
# 1      10/2013  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 2      05/2013  \n,Gasoline,\n   90 kW (122 hp),  ['\n', ['Dealer\n']]
# 3      06/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
# 4      10/2015  \n,Gasoline,\n   92 kW (125 hp),  ['\n', ['Dealer\n']]
#
#        body_type        type   drivetrain seats doors  \
# 0  \n,Compact,\n  \n,Used,\n  \n,Front,\n   \n5   \n3
# 1  \n,Compact,\n  \n,Used,\n  \n,Front,\n   \n5   \n5
# 2  \n,Compact,\n  \n,Used,\n   \n,None,\n   \n5   \n5
# 3  \n,Compact,\n  \n,Used,\n   \n,None,\n   \n5   \n5
# 4  \n,Compact,\n  \n,Used,\n  \n,Front,\n   \n4   \n3
#
#                country_version offer_number        warranty         Mileage  \
# 0         Country version,None   \nSJ-112-R  \n,6 months,\n  [['\n'], ['']]
# 1         Country version,None     \n809725      \n,None,\n  [['\n'], ['']]
# 2         Country version,None   \n1-KJK-58      \n,None,\n  [['\n'], ['']]
# 3  Country version,Netherlands    \n2601307  \n,6 months,\n  [['\n'], ['']]
# 4         Country version,None   \nL-847-SK  \n,6 months,\n  [['\n'], ['']]
#
#   first_registration production_date general_inspection last_service  \
# 0            08/2003            None            05/2022         None
# 1            10/2013            None               None         None
# 2            05/2013            None            03/2022         None
# 3            06/2015            2015                New         None
# 4            10/2015            None               None         None
#
#   full_service_history non_smoker_vehicle      previous_owner  \
# 0            \n,Yes,\n         \n,None,\n  [['\n'], ['None']]
# 1            \n,Yes,\n         \n,None,\n  [['\n'], ['None']]
# 2           \n,None,\n         \n,None,\n  [['\n'], ['None']]
# 3            \n,Yes,\n          \n,Yes,\n  [['\n'], ['None']]
# 4            \n,Yes,\n         \n,None,\n  [['\n'], ['None']]
#
#   last_timing_belt_change                  Power          Gearbox  \
# 0      [['\n'], ['None']]  \n,110 kW (150 hp),\n  \n,Automatic,\n
# 1      [['\n'], ['None']]   \n,92 kW (125 hp),\n  \n,Automatic,\n
# 2      [['\n'], ['None']]   \n,90 kW (122 hp),\n  \n,Automatic,\n
# 3      [['\n'], ['None']]   \n,92 kW (125 hp),\n  \n,Automatic,\n
# 4      [['\n'], ['None']]   \n,92 kW (125 hp),\n  \n,Automatic,\n
#
#       engine_size       gears cylinders    empty_weight       Fuel_type  \
# 0  \n,1,984 cc,\n  \n,None,\n   \n,4,\n  \n,1,280 kg,\n  \n,Super 95,\n
# 1  \n,1,395 cc,\n  \n,None,\n   \n,4,\n  \n,1,200 kg,\n  \n,Gasoline,\n
# 2  \n,1,395 cc,\n  \n,None,\n   \n,4,\n  \n,1,200 kg,\n  \n,Gasoline,\n
# 3  \n,1,395 cc,\n  \n,None,\n   \n,4,\n      \n,None,\n  \n,Gasoline,\n
# 4  \n,1,395 cc,\n     \n,7,\n   \n,4,\n  \n,1,105 kg,\n  \n,Gasoline,\n
#
#                                     fuel_consumption  \
# 0                                         \n,None,\n
# 1   ['\n', ['4.9 l/100 km (comb.)', ' ', ' '], '\n']
# 2     ['\n', ['5 l/100 km (comb.)', ' ', ' '], '\n']
# 3  ['\n', ['0 l/100 km (comb.)', '0 l/100 km (cit...
# 4  ['\n', ['4.8 l/100 km (comb.)', '5.9 l/100 km ...
#
#                    co2_emissions emission_class emissions_sticker  \
# 0  ['\n', [' ', ' ', ' '], '\n']   \n,Euro 4,\n        \n,None,\n
# 1                     \n,None,\n     \n,None,\n        \n,None,\n
# 2         \n,116 g/km (comb.),\n     \n,None,\n        \n,None,\n
# 3                     \n,None,\n     \n,None,\n        \n,None,\n
# 4         \n,111 g/km (comb.),\n   \n,Euro 6,\n        \n,None,\n
#
#                            \nComfort & Convenience\n  \
# 0  [['Air conditioning', 'Armrest', 'Automatic cl...
# 1  [['Air conditioning', 'Automatic climate contr...
# 2  [['Air conditioning', 'Armrest', 'Cruise contr...
# 3  [['Air conditioning', 'Armrest', 'Automatic cl...
# 4  [['Air conditioning', 'Armrest', 'Automatic cl...
#
#                            \nEntertainment & Media\n  \
# 0                           [['CD player', 'Radio']]
# 1                           [['CD player', 'Radio']]
# 2  [['Bluetooth', 'CD player', 'Hands-free equipm...
# 3  [['Bluetooth', 'CD player', 'On-board computer...
# 4  [['CD player', 'MP3', 'On-board computer', 'Ra...
#
#                                \nSafety & Security\n  \
# 0  [['ABS', 'Alarm system', 'Central door lock', ...
# 1  [['Alarm system', 'Central door lock', 'Centra...
# 2  [['ABS', 'Central door lock', 'Central door lo...
# 3  [['ABS', 'Central door lock with remote contro...
# 4  [['ABS', 'Alarm system', 'Bi-Xenon headlights'...
#
#                                               extras    \ncolour  \
# 0                                 [['Alloy wheels']]   \n4, Grey
# 1                           [['Alloy wheels (16")']]  \n4, White
# 2                      [['Alloy wheels', 'Spoiler']]  \n4, Black
# 3                           [['Alloy wheels (15")']]   \n4, Grey
# 4  [['Alloy wheels (17")', 'Shift paddles', 'Spor...  \n4, Black
#
#   \nmanufacturer_color            \npaint   upholstery_colour   \
# 0                 None  \npaint, Metallic  \nupholstery, Black
# 1                 None               None  \nupholstery, Black
# 2                 None  \npaint, Metallic                 None
# 3                 None  \npaint, Metallic                 None
# 4                 None               None  \nupholstery, Black
#
#          upholstery
# 0         \n8, Cloth
# 1         \n8, Cloth
# 2               None
# 3               None
# 4  \n8, Part leather

# %%
# Drop Duplicated Columns and Url column
df.drop(['url', 'Mileage', 'Power'], axis=1, inplace= True)

# %%
df.columns
# Out:
# Index(['location', 'make', 'model', 'short_description', 'price', 'mileage',
#        'gearbox', 'registration', 'fuel_type', 'power', 'seller', 'body_type',
#        'type', 'drivetrain', 'seats', 'doors', 'country_version',
#        'offer_number', 'warranty', 'first_registration', 'production_date',
#        'general_inspection', 'last_service', 'full_service_history',
#        'non_smoker_vehicle', 'previous_owner', 'last_timing_belt_change',
#        'Gearbox', 'engine_size', 'gears', 'cylinders', 'empty_weight',
#        'Fuel_type', 'fuel_consumption', 'co2_emissions', 'emission_class',
#        'emissions_sticker', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nSafety & Security\n', 'extras',
#        '\ncolour', '\nmanufacturer_color', '\npaint', ' upholstery_colour ',
#        ' upholstery '],
#       dtype='object')

# %%
# 1 - Rename Columns (move unwanted characters from column names)
df.columns = ['location', 'make', 'model', 'short_description', 'price','mileage_km', 'gearbox', 'registration', 'fuel_type', 'power', 'seller',
       'body_type', 'type', 'drivetrain', 'seats', 'doors', 'country_version','offer_number', 'warranty_months',  'first_registration',
       'production_date', 'general_inspection', 'last_service','full_service_history', 'non_smoker_vehicle', 'previous_owner',
       'last_timing_belt_change', 'Gearbox', 'engine_size_cc', 'gears','cylinders', 'empty_weight_kg', 'Fuel_type', 'fuel_consumption',
       'co2_emissions', 'emission_class', 'emissions_sticker','Comfort & Convenience', 'Entertainment & Media',
       'Safety & Security', 'extras', 'colour', 'manufacturer_color','paint', 'upholstery_colour', 'upholstery']

# %%
# 2 - Removing unwanted Chracters from data
# Except these colums ====> url , short_description, registration, first_registration, general_inspection, Comfort & Convenience, Entertainment & Media, Safety & Security, extras
clmns = ['location', 'make', 'model', 'price','mileage_km', 'gearbox', 'fuel_type', 'power', 'seller',
       'body_type', 'type', 'drivetrain', 'seats', 'doors', 'country_version','offer_number', 'warranty_months',
       'production_date', 'last_service','full_service_history', 'non_smoker_vehicle', 'previous_owner',
       'last_timing_belt_change', 'Gearbox', 'engine_size_cc', 'gears','cylinders', 'empty_weight_kg', 'Fuel_type', 'fuel_consumption',
       'co2_emissions', 'emission_class', 'emissions_sticker',
       'colour', 'manufacturer_color','paint', 'upholstery_colour', 'upholstery']

for column in clmns:
    df[column] = df[column].str.replace(r'\W', '')
    
df.head(2)
# Out:
#        location  make model  \
# 0  LOONOPZANDNL  Audi    A3
# 1     HEERLENNL  Audi    A3
#
#                                    short_description    price mileage_km  \
# 0                          2.0 FSI Ambition Pro Line   n4450n   191066km
# 1  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...  n12950n    94758km
#
#      gearbox registration fuel_type       power    seller body_type  type  \
# 0  Automatic      08/2003  Gasoline  110kW150hp  nDealern   Compact  Used
# 1  Automatic      10/2013  Gasoline   92kW125hp  nDealern   Compact  Used
#
#   drivetrain seats doors     country_version offer_number warranty_months  \
# 0      Front     5     3  CountryversionNone       SJ112R         6months
# 1      Front     5     5  CountryversionNone       809725            None
#
#   first_registration production_date general_inspection last_service  \
# 0            08/2003            None            05/2022         None
# 1            10/2013            None               None         None
#
#   full_service_history non_smoker_vehicle previous_owner  \
# 0                  Yes               None          nNone
# 1                  Yes               None          nNone
#
#   last_timing_belt_change    Gearbox engine_size_cc gears cylinders  \
# 0                   nNone  Automatic         1984cc  None         4
# 1                   nNone  Automatic         1395cc  None         4
#
#   empty_weight_kg Fuel_type fuel_consumption co2_emissions emission_class  \
# 0          1280kg   Super95             None            nn          Euro4
# 1          1200kg  Gasoline   n49l100kmcombn          None           None
#
#   emissions_sticker                              Comfort & Convenience  \
# 0              None  [['Air conditioning', 'Armrest', 'Automatic cl...
# 1              None  [['Air conditioning', 'Automatic climate contr...
#
#       Entertainment & Media  \
# 0  [['CD player', 'Radio']]
# 1  [['CD player', 'Radio']]
#
#                                    Safety & Security  \
# 0  [['ABS', 'Alarm system', 'Central door lock', ...
# 1  [['Alarm system', 'Central door lock', 'Centra...
#
#                      extras  colour manufacturer_color          paint  \
# 0        [['Alloy wheels']]   4Grey               None  paintMetallic
# 1  [['Alloy wheels (16")']]  4White               None           None
#
#   upholstery_colour upholstery
# 0   upholsteryBlack     8Cloth
# 1   upholsteryBlack     8Cloth

# %%
# 3 - Delete NL from Location
df['location'] = df['location'].str.replace(r'(?P<name>NL)', '')

# Delete n from columns
L01 = ['seller', 'price', 'previous_owner', 'last_timing_belt_change', 'fuel_consumption']
for i in L01:
    df[i] = df[i].str.replace('n', '')

# Delete [ ] from L02    
L02 = ['Comfort & Convenience', 'Entertainment & Media', 'Safety & Security', 'extras']
for i in L02:
    df[i] = df[i].str.replace('[', '')
    df[i] = df[i].str.replace(']', '')
    
# delete 4 from colour
df['colour'] = df['colour'].str.replace('4', '')

# Delete paint from paint column
df['paint'] = df['paint'].str.replace('paint', '')

# Delete upholstery from upholstery_colour
df['upholstery_colour'] = df['upholstery_colour'].str.replace('upholstery', '')

# Delete 8 from upholstery
df['upholstery'] = df['upholstery'].str.replace('8', '')

df.head(2)
# Out:
#      location  make model                                  short_description  \
# 0  LOONOPZAND  Audi    A3                          2.0 FSI Ambition Pro Line
# 1     HEERLEN  Audi    A3  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
#
#    price mileage_km    gearbox registration fuel_type       power  seller  \
# 0   4450   191066km  Automatic      08/2003  Gasoline  110kW150hp  Dealer
# 1  12950    94758km  Automatic      10/2013  Gasoline   92kW125hp  Dealer
#
#   body_type  type drivetrain seats doors     country_version offer_number  \
# 0   Compact  Used      Front     5     3  CountryversionNone       SJ112R
# 1   Compact  Used      Front     5     5  CountryversionNone       809725
#
#   warranty_months first_registration production_date general_inspection  \
# 0         6months            08/2003            None            05/2022
# 1            None            10/2013            None               None
#
#   last_service full_service_history non_smoker_vehicle previous_owner  \
# 0         None                  Yes               None            Noe
# 1         None                  Yes               None            Noe
#
#   last_timing_belt_change    Gearbox engine_size_cc gears cylinders  \
# 0                     Noe  Automatic         1984cc  None         4
# 1                     Noe  Automatic         1395cc  None         4
#
#   empty_weight_kg Fuel_type fuel_consumption co2_emissions emission_class  \
# 0          1280kg   Super95              Noe            nn          Euro4
# 1          1200kg  Gasoline     49l100kmcomb          None           None
#
#   emissions_sticker                              Comfort & Convenience  \
# 0              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 1              None  'Air conditioning', 'Automatic climate control...
#
#   Entertainment & Media                                  Safety & Security  \
# 0  'CD player', 'Radio'  'ABS', 'Alarm system', 'Central door lock', 'C...
# 1  'CD player', 'Radio'  'Alarm system', 'Central door lock', 'Central ...
#
#                  extras colour manufacturer_color     paint upholstery_colour  \
# 0        'Alloy wheels'   Grey               None  Metallic             Black
# 1  'Alloy wheels (16")'  White               None      None             Black
#
#   upholstery
# 0      Cloth
# 1      Cloth

# %%
df['mileage_km'] = df['mileage_km'].str.replace('km', '')
df['warranty_months'] = df['warranty_months'].str.replace('months', '')
df['engine_size_cc'] = df['engine_size_cc'].str.replace('cc', '')
df['empty_weight_kg'] = df['empty_weight_kg'].str.replace('kg', '')
df['country_version'] = df['country_version'].str.replace('Countryversion', '')

df.head(2)
# Out:
#      location  make model                                  short_description  \
# 0  LOONOPZAND  Audi    A3                          2.0 FSI Ambition Pro Line
# 1     HEERLEN  Audi    A3  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
#
#    price mileage_km    gearbox registration fuel_type       power  seller  \
# 0   4450     191066  Automatic      08/2003  Gasoline  110kW150hp  Dealer
# 1  12950      94758  Automatic      10/2013  Gasoline   92kW125hp  Dealer
#
#   body_type  type drivetrain seats doors country_version offer_number  \
# 0   Compact  Used      Front     5     3            None       SJ112R
# 1   Compact  Used      Front     5     5            None       809725
#
#   warranty_months first_registration production_date general_inspection  \
# 0               6            08/2003            None            05/2022
# 1            None            10/2013            None               None
#
#   last_service full_service_history non_smoker_vehicle previous_owner  \
# 0         None                  Yes               None            Noe
# 1         None                  Yes               None            Noe
#
#   last_timing_belt_change    Gearbox engine_size_cc gears cylinders  \
# 0                     Noe  Automatic           1984  None         4
# 1                     Noe  Automatic           1395  None         4
#
#   empty_weight_kg Fuel_type fuel_consumption co2_emissions emission_class  \
# 0            1280   Super95              Noe            nn          Euro4
# 1            1200  Gasoline     49l100kmcomb          None           None
#
#   emissions_sticker                              Comfort & Convenience  \
# 0              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 1              None  'Air conditioning', 'Automatic climate control...
#
#   Entertainment & Media                                  Safety & Security  \
# 0  'CD player', 'Radio'  'ABS', 'Alarm system', 'Central door lock', 'C...
# 1  'CD player', 'Radio'  'Alarm system', 'Central door lock', 'Central ...
#
#                  extras colour manufacturer_color     paint upholstery_colour  \
# 0        'Alloy wheels'   Grey               None  Metallic             Black
# 1  'Alloy wheels (16")'  White               None      None             Black
#
#   upholstery
# 0      Cloth
# 1      Cloth

# %%
df1 = df.copy()

# %%
L03 = ['price', 'engine_size_cc', 'empty_weight_kg', 'cylinders']
for i in L03:
    df[i] = df[i].replace('', np.NaN)
    df[i] = df[i].replace('None', np.NaN)
    df[i] = df[i].astype(float)

df.describe()
# Out:
#           price  engine_size_cc  cylinders  empty_weight_kg
# count     69534           65265      64809            69500
# mean      24369            1771          4             1433
# std      468620             702          1              321
# min           1               0          1                1
# 25%        8945            1390          4             1234
# 50%       17450            1598          4             1382
# 75%       28935            1995          4             1591
# max   123456789           65535         12             4200

# %%
# Find the rows which have no price
price_null_tf = (df['price'].isnull())
price_null = (df[price_null_tf])
price_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1570 entries, 54 to 71065
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 1570 non-null   object
#  1   make                     1570 non-null   object
#  2   model                    1570 non-null   object
#  3   short_description        1567 non-null   object
#  4   price                    0 non-null      float64
#  5   mileage_km               1570 non-null   object
#  6   gearbox                  1570 non-null   object
#  7   registration             1570 non-null   object
#  8   fuel_type                1570 non-null   object
#  9   power                    1570 non-null   object
#  10  seller                   1570 non-null   object
#  11  body_type                1570 non-null   object
#  12  type                     1570 non-null   object
#  13  drivetrain               1570 non-null   object
#  14  seats                    1570 non-null   object
#  15  doors                    1570 non-null   object
#  16  country_version          1570 non-null   object
#  17  offer_number             1570 non-null   object
#  18  warranty_months          1570 non-null   object
#  19  first_registration       1570 non-null   object
#  20  production_date          1570 non-null   object
#  21  general_inspection       1570 non-null   object
#  22  last_service             1570 non-null   object
#  23  full_service_history     1570 non-null   object
#  24  non_smoker_vehicle       1570 non-null   object
#  25  previous_owner           1570 non-null   object
#  26  last_timing_belt_change  1570 non-null   object
#  27  Gearbox                  1570 non-null   object
#  28  engine_size_cc           1477 non-null   float64
#  29  gears                    1570 non-null   object
#  30  cylinders                1459 non-null   float64
#  31  empty_weight_kg          1549 non-null   float64
#  32  Fuel_type                1570 non-null   object
#  33  fuel_consumption         1570 non-null   object
#  34  co2_emissions            1570 non-null   object
#  35  emission_class           1570 non-null   object
#  36  emissions_sticker        1570 non-null   object
#  37  Comfort & Convenience    1570 non-null   object
#  38  Entertainment & Media    1570 non-null   object
#  39  Safety & Security        1570 non-null   object
#  40  extras                   1570 non-null   object
#  41  colour                   1570 non-null   object
#  42  manufacturer_color       1570 non-null   object
#  43  paint                    1570 non-null   object
#  44  upholstery_colour        1570 non-null   object
#  45  upholstery               1570 non-null   object
# dtypes: float64(4), object(42)
# memory usage: 576.5+ KB

# %%
df.head(2)
# Out:
#      location  make model                                  short_description  \
# 0  LOONOPZAND  Audi    A3                          2.0 FSI Ambition Pro Line
# 1     HEERLEN  Audi    A3  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
#
#    price mileage_km    gearbox registration fuel_type       power  seller  \
# 0   4450     191066  Automatic      08/2003  Gasoline  110kW150hp  Dealer
# 1  12950      94758  Automatic      10/2013  Gasoline   92kW125hp  Dealer
#
#   body_type  type drivetrain seats doors country_version offer_number  \
# 0   Compact  Used      Front     5     3            None       SJ112R
# 1   Compact  Used      Front     5     5            None       809725
#
#   warranty_months first_registration production_date general_inspection  \
# 0               6            08/2003            None            05/2022
# 1            None            10/2013            None               None
#
#   last_service full_service_history non_smoker_vehicle previous_owner  \
# 0         None                  Yes               None            Noe
# 1         None                  Yes               None            Noe
#
#   last_timing_belt_change    Gearbox  engine_size_cc gears  cylinders  \
# 0                     Noe  Automatic            1984  None          4
# 1                     Noe  Automatic            1395  None          4
#
#    empty_weight_kg Fuel_type fuel_consumption co2_emissions emission_class  \
# 0             1280   Super95              Noe            nn          Euro4
# 1             1200  Gasoline     49l100kmcomb          None           None
#
#   emissions_sticker                              Comfort & Convenience  \
# 0              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 1              None  'Air conditioning', 'Automatic climate control...
#
#   Entertainment & Media                                  Safety & Security  \
# 0  'CD player', 'Radio'  'ABS', 'Alarm system', 'Central door lock', 'C...
# 1  'CD player', 'Radio'  'Alarm system', 'Central door lock', 'Central ...
#
#                  extras colour manufacturer_color     paint upholstery_colour  \
# 0        'Alloy wheels'   Grey               None  Metallic             Black
# 1  'Alloy wheels (16")'  White               None      None             Black
#
#   upholstery
# 0      Cloth
# 1      Cloth

# %%
L04 = ['power_kw', 'power_hp']
df[L04] = df.power.str.split('kW', expand= True)   
df['power_hp'] = df['power_hp'].str.replace('hp', '').replace('None', np.NaN) 
df['power_kw'] = df['power_kw'].str.replace('kg', '').replace('None', np.NaN)     
df[L04] = df[L04].astype(float)
df = df.drop(['power'], axis=1)
df.head(2)
# Out:
#      location  make model                                  short_description  \
# 0  LOONOPZAND  Audi    A3                          2.0 FSI Ambition Pro Line
# 1     HEERLEN  Audi    A3  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
#
#    price mileage_km    gearbox registration fuel_type  seller body_type  type  \
# 0   4450     191066  Automatic      08/2003  Gasoline  Dealer   Compact  Used
# 1  12950      94758  Automatic      10/2013  Gasoline  Dealer   Compact  Used
#
#   drivetrain seats doors country_version offer_number warranty_months  \
# 0      Front     5     3            None       SJ112R               6
# 1      Front     5     5            None       809725            None
#
#   first_registration production_date general_inspection last_service  \
# 0            08/2003            None            05/2022         None
# 1            10/2013            None               None         None
#
#   full_service_history non_smoker_vehicle previous_owner  \
# 0                  Yes               None            Noe
# 1                  Yes               None            Noe
#
#   last_timing_belt_change    Gearbox  engine_size_cc gears  cylinders  \
# 0                     Noe  Automatic            1984  None          4
# 1                     Noe  Automatic            1395  None          4
#
#    empty_weight_kg Fuel_type fuel_consumption co2_emissions emission_class  \
# 0             1280   Super95              Noe            nn          Euro4
# 1             1200  Gasoline     49l100kmcomb          None           None
#
#   emissions_sticker                              Comfort & Convenience  \
# 0              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 1              None  'Air conditioning', 'Automatic climate control...
#
#   Entertainment & Media                                  Safety & Security  \
# 0  'CD player', 'Radio'  'ABS', 'Alarm system', 'Central door lock', 'C...
# 1  'CD player', 'Radio'  'Alarm system', 'Central door lock', 'Central ...
#
#                  extras colour manufacturer_color     paint upholstery_colour  \
# 0        'Alloy wheels'   Grey               None  Metallic             Black
# 1  'Alloy wheels (16")'  White               None      None             Black
#
#   upholstery  power_kw  power_hp
# 0      Cloth       110       150
# 1      Cloth        92       125

# %%
df.describe()
# Out:
#           price  engine_size_cc  cylinders  empty_weight_kg  power_kw  \
# count     69534           65265      64809            69500     65045
# mean      24369            1771          4             1433       116
# std      468620             702          1              321        59
# min           1               0          1                1         1
# 25%        8945            1390          4             1234        82
# 50%       17450            1598          4             1382       103
# 75%       28935            1995          4             1591       132
# max   123456789           65535         12             4200      3500
#
#        power_hp
# count     65041
# mean        157
# std          75
# min           1
# 25%         111
# 50%         140
# 75%         179
# max        2173

# %%
L05 = ['registration', 'first_registration', 'general_inspection']
for i in L05:
    df[i] = pd.to_datetime(df[i], format= '%m/%Y', errors= 'coerce')

df['production_date'] = pd.to_datetime(df['production_date'], format= '%Y', errors= 'coerce')
df.head()
# Out:
#        location  make model  \
# 0    LOONOPZAND  Audi    A3
# 1       HEERLEN  Audi    A3
# 2         BREDA  Audi    A3
# 3  BAARLENASSAU  Audi    A1
# 4       ZUTPHEN  Audi    A1
#
#                                    short_description  price mileage_km  \
# 0                          2.0 FSI Ambition Pro Line   4450     191066
# 1  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...  12950      94758
# 2  1.4 TFSI Attraction Pro Line [ Navi Airco Crui...  12445     160883
# 3    1.4 TFSI Sportback Pro-Line Aut. S-Tronic Navi.  12450     145102
# 4  S-Line | Automaat | Navigatie | Cruise-/Climat...  14945     119666
#
#      gearbox registration fuel_type  seller body_type  type drivetrain seats  \
# 0  Automatic   2003-08-01  Gasoline  Dealer   Compact  Used      Front     5
# 1  Automatic   2013-10-01  Gasoline  Dealer   Compact  Used      Front     5
# 2  Automatic   2013-05-01  Gasoline  Dealer   Compact  Used       None     5
# 3  Automatic   2015-06-01  Gasoline  Dealer   Compact  Used       None     5
# 4  Automatic   2015-10-01  Gasoline  Dealer   Compact  Used      Front     4
#
#   doors country_version offer_number warranty_months first_registration  \
# 0     3            None       SJ112R               6         2003-08-01
# 1     5            None       809725            None         2013-10-01
# 2     5            None       1KJK58            None         2013-05-01
# 3     5     Netherlands      2601307               6         2015-06-01
# 4     3            None       L847SK               6         2015-10-01
#
#   production_date general_inspection last_service full_service_history  \
# 0             NaT         2022-05-01         None                  Yes
# 1             NaT                NaT         None                  Yes
# 2             NaT         2022-03-01         None                 None
# 3      2015-01-01                NaT         None                  Yes
# 4             NaT                NaT         None                  Yes
#
#   non_smoker_vehicle previous_owner last_timing_belt_change    Gearbox  \
# 0               None            Noe                     Noe  Automatic
# 1               None            Noe                     Noe  Automatic
# 2               None            Noe                     Noe  Automatic
# 3                Yes            Noe                     Noe  Automatic
# 4               None            Noe                     Noe  Automatic
#
#    engine_size_cc gears  cylinders  empty_weight_kg Fuel_type  \
# 0            1984  None          4             1280   Super95
# 1            1395  None          4             1200  Gasoline
# 2            1395  None          4             1200  Gasoline
# 3            1395  None          4              NaN  Gasoline
# 4            1395     7          4             1105  Gasoline
#
#                          fuel_consumption co2_emissions emission_class  \
# 0                                     Noe            nn          Euro4
# 1                            49l100kmcomb          None           None
# 2                             5l100kmcomb    116gkmcomb           None
# 3     0l100kmcomb0l100kmcity0l100kmcoutry          None           None
# 4  48l100kmcomb59l100kmcity42l100kmcoutry    111gkmcomb          Euro6
#
#   emissions_sticker                              Comfort & Convenience  \
# 0              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 1              None  'Air conditioning', 'Automatic climate control...
# 2              None  'Air conditioning', 'Armrest', 'Cruise control...
# 3              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 4              None  'Air conditioning', 'Armrest', 'Automatic clim...
#
#                                Entertainment & Media  \
# 0                               'CD player', 'Radio'
# 1                               'CD player', 'Radio'
# 2  'Bluetooth', 'CD player', 'Hands-free equipmen...
# 3  'Bluetooth', 'CD player', 'On-board computer',...
# 4   'CD player', 'MP3', 'On-board computer', 'Radio'
#
#                                    Safety & Security  \
# 0  'ABS', 'Alarm system', 'Central door lock', 'C...
# 1  'Alarm system', 'Central door lock', 'Central ...
# 2  'ABS', 'Central door lock', 'Central door lock...
# 3  'ABS', 'Central door lock with remote control'...
# 4  'ABS', 'Alarm system', 'Bi-Xenon headlights', ...
#
#                                               extras colour  \
# 0                                     'Alloy wheels'   Grey
# 1                               'Alloy wheels (16")'  White
# 2                          'Alloy wheels', 'Spoiler'  Black
# 3                               'Alloy wheels (15")'   Grey
# 4  'Alloy wheels (17")', 'Shift paddles', 'Sport ...  Black
#
#   manufacturer_color     paint upholstery_colour   upholstery  power_kw  \
# 0               None  Metallic             Black        Cloth       110
# 1               None      None             Black        Cloth        92
# 2               None  Metallic              None         None        90
# 3               None  Metallic              None         None        92
# 4               None      None             Black  Partleather        92
#
#    power_hp
# 0       150
# 1       125
# 2       122
# 3       125
# 4       125

# %%
df_dates = pd.DataFrame({'registration':  df.registration,
                         'first_registration' : df.first_registration,
                         'production_date' : df.production_date,
                         'general_inspection' : df.general_inspection,
                        'last_timing_belt_change' : df.last_timing_belt_change})
df_dates.head()
# Out:
#   registration first_registration production_date general_inspection  \
# 0   2003-08-01         2003-08-01             NaT         2022-05-01
# 1   2013-10-01         2013-10-01             NaT                NaT
# 2   2013-05-01         2013-05-01             NaT         2022-03-01
# 3   2015-06-01         2015-06-01      2015-01-01                NaT
# 4   2015-10-01         2015-10-01             NaT                NaT
#
#   last_timing_belt_change
# 0                     Noe
# 1                     Noe
# 2                     Noe
# 3                     Noe
# 4                     Noe

# %%
L05 = ['registration', 'first_registration', 'general_inspection']
for i in L05:
    df_dates[i] = pd.to_datetime(df_dates[i], format= '%m/%Y', errors= 'coerce')

df_dates['production_date'] = pd.to_datetime(df_dates['production_date'], format= '%Y', errors= 'coerce')
df_dates['last_timing_belt_change'] = pd.to_datetime(df_dates['last_timing_belt_change'], format= '%m%Y', errors= 'coerce')
df_dates.head()
# Out:
#   registration first_registration production_date general_inspection  \
# 0   2003-08-01         2003-08-01             NaT         2022-05-01
# 1   2013-10-01         2013-10-01             NaT                NaT
# 2   2013-05-01         2013-05-01             NaT         2022-03-01
# 3   2015-06-01         2015-06-01      2015-01-01                NaT
# 4   2015-10-01         2015-10-01             NaT                NaT
#
#   last_timing_belt_change
# 0                     NaT
# 1                     NaT
# 2                     NaT
# 3                     NaT
# 4                     NaT

# %%
df_dates.describe()
# Out:
#                registration   first_registration      production_date  \
# count                 71056                71064                 7416
# unique                  300                  300                   25
# top     2021-01-01 00:00:00  2021-01-01 00:00:00  2021-01-01 00:00:00
# freq                   3270                 3270                 1148
# first   1976-03-01 00:00:00  1976-03-01 00:00:00  1997-01-01 00:00:00
# last    2028-07-01 00:00:00  2028-07-01 00:00:00  2022-01-01 00:00:00
#
#          general_inspection last_timing_belt_change
# count                 36486                     950
# unique                   96                      84
# top     2022-06-01 00:00:00     2021-06-01 00:00:00
# freq                   2457                      48
# first   2014-11-01 00:00:00     1900-01-01 00:00:00
# last    2026-11-01 00:00:00     2021-12-01 00:00:00

# %%
df.head(2)
# Out:
#      location  make model                                  short_description  \
# 0  LOONOPZAND  Audi    A3                          2.0 FSI Ambition Pro Line
# 1     HEERLEN  Audi    A3  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
#
#    price mileage_km    gearbox registration fuel_type  seller body_type  type  \
# 0   4450     191066  Automatic   2003-08-01  Gasoline  Dealer   Compact  Used
# 1  12950      94758  Automatic   2013-10-01  Gasoline  Dealer   Compact  Used
#
#   drivetrain seats doors country_version offer_number warranty_months  \
# 0      Front     5     3            None       SJ112R               6
# 1      Front     5     5            None       809725            None
#
#   first_registration production_date general_inspection last_service  \
# 0         2003-08-01             NaT         2022-05-01         None
# 1         2013-10-01             NaT                NaT         None
#
#   full_service_history non_smoker_vehicle previous_owner  \
# 0                  Yes               None            Noe
# 1                  Yes               None            Noe
#
#   last_timing_belt_change    Gearbox  engine_size_cc gears  cylinders  \
# 0                     Noe  Automatic            1984  None          4
# 1                     Noe  Automatic            1395  None          4
#
#    empty_weight_kg Fuel_type fuel_consumption co2_emissions emission_class  \
# 0             1280   Super95              Noe            nn          Euro4
# 1             1200  Gasoline     49l100kmcomb          None           None
#
#   emissions_sticker                              Comfort & Convenience  \
# 0              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 1              None  'Air conditioning', 'Automatic climate control...
#
#   Entertainment & Media                                  Safety & Security  \
# 0  'CD player', 'Radio'  'ABS', 'Alarm system', 'Central door lock', 'C...
# 1  'CD player', 'Radio'  'Alarm system', 'Central door lock', 'Central ...
#
#                  extras colour manufacturer_color     paint upholstery_colour  \
# 0        'Alloy wheels'   Grey               None  Metallic             Black
# 1  'Alloy wheels (16")'  White               None      None             Black
#
#   upholstery  power_kw  power_hp
# 0      Cloth       110       150
# 1      Cloth        92       125

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71104 entries, 0 to 71103
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 71104 non-null  object
#  1   make                     71104 non-null  object
#  2   model                    71104 non-null  object
#  3   short_description        70935 non-null  object
#  4   price                    69534 non-null  float64
#  5   mileage_km               71104 non-null  object
#  6   gearbox                  71104 non-null  object
#  7   registration             71056 non-null  datetime64[ns]
#  8   fuel_type                71104 non-null  object
#  9   seller                   71104 non-null  object
#  10  body_type                71104 non-null  object
#  11  type                     71104 non-null  object
#  12  drivetrain               71104 non-null  object
#  13  seats                    71104 non-null  object
#  14  doors                    71104 non-null  object
#  15  country_version          71104 non-null  object
#  16  offer_number             71104 non-null  object
#  17  warranty_months          71104 non-null  object
#  18  first_registration       71064 non-null  datetime64[ns]
#  19  production_date          7416 non-null   datetime64[ns]
#  20  general_inspection       36486 non-null  datetime64[ns]
#  21  last_service             71104 non-null  object
#  22  full_service_history     71104 non-null  object
#  23  non_smoker_vehicle       71104 non-null  object
#  24  previous_owner           71104 non-null  object
#  25  last_timing_belt_change  71104 non-null  object
#  26  Gearbox                  71104 non-null  object
#  27  engine_size_cc           65265 non-null  float64
#  28  gears                    71104 non-null  object
#  29  cylinders                64809 non-null  float64
#  30  empty_weight_kg          69500 non-null  float64
#  31  Fuel_type                71104 non-null  object
#  32  fuel_consumption         71104 non-null  object
#  33  co2_emissions            71104 non-null  object
#  34  emission_class           71104 non-null  object
#  35  emissions_sticker        71104 non-null  object
#  36  Comfort & Convenience    71104 non-null  object
#  37  Entertainment & Media    71104 non-null  object
#  38  Safety & Security        71104 non-null  object
#  39  extras                   71104 non-null  object
#  40  colour                   71104 non-null  object
#  41  manufacturer_color       71104 non-null  object
#  42  paint                    71104 non-null  object
#  43  upholstery_colour        71104 non-null  object
#  44  upholstery               71104 non-null  object
#  45  power_kw                 65045 non-null  float64
#  46  power_hp                 65041 non-null  float64
# dtypes: datetime64[ns](4), float64(6), object(37)
# memory usage: 25.5+ MB

# %%
plt.figure(figsize = (15,10))
sns.countplot(y = df.make, order=df.make.value_counts(ascending=True).index)
plt.xlabel('Count of Cars')
plt.ylabel('Company')
plt.title('Car Compamies with Car')
plt.show()

# %%
df_dates.loc[0,'first_registration'].year
# Out:
# 2003

# %%
# Save Csv df01
#df.to_csv('df01.csv')

# %%
df.first_registration.dt.year.value_counts().plot(kind= 'bar');

# %%
plt.figure(figsize = (15,10))
sns.countplot(y = df.make,
              order=df.make.value_counts(ascending=True).index,
             hue= df.registration.dt.year,
              hue_order= [2020, 2021]
             )
plt.xlabel('Count of Cars')
plt.ylabel('Company')
plt.title('Car Compamies with Car')
plt.show()

# %%
df.price.isnull().sum()
# Out:
# 1570

# %%
df[df.price < 10]
# Out:
#        location     make   model  \
# 14552  HARMELEN     Ford    KaKa
# 25789     Breda     Opel  Vectra
# 44337     Breda     Fiat     500
# 55658   GAMEREN  Peugeot     206
#
#                                        short_description  price mileage_km  \
# 14552   1.2 Titanium-X 2012. *Airco*NL-Auto*Distriem vv*      1     126871
# 25789                                    GTS 2.2-16V DGi      2     212623
# 44337                                         1.2 Lounge      1     157893
# 55658  1.6 16V 3Drs QUIKSILVER Premium *Clima *Nette ...      1     112637
#
#          gearbox registration fuel_type  seller body_type  type drivetrain  \
# 14552     Manual   2012-01-01  Gasoline  Dealer   Compact  Used      Front
# 25789     Manual   2004-07-01  Gasoline  Dealer   Compact  Used       None
# 44337  Automatic   2009-03-01  Gasoline  Dealer   Compact  Used       None
# 55658     Manual   2003-06-01  Gasoline  Dealer   Compact  Used       None
#
#       seats doors country_version offer_number warranty_months  \
# 14552     4     3            None       48SXB8            None
# 25789     5     5            None       79PJVK            None
# 44337     4     3            None       43HZG8            None
# 55658     5     3     Netherlands       10LVNB            None
#
#       first_registration production_date general_inspection last_service  \
# 14552         2012-01-01             NaT                NaT         None
# 25789         2004-07-01             NaT         2022-03-01         None
# 44337         2009-03-01             NaT         2022-08-01         None
# 55658         2003-06-01      2003-01-01         2022-06-01         None
#
#       full_service_history non_smoker_vehicle previous_owner  \
# 14552                 None               None            Noe
# 25789                  Yes               None            Noe
# 44337                  Yes               None            Noe
# 55658                  Yes               None            Noe
#
#       last_timing_belt_change    Gearbox  engine_size_cc gears  cylinders  \
# 14552                     Noe     Manual            1242     5          4
# 25789                     Noe     Manual            2198     6          4
# 44337                     Noe  Automatic            1242     5          4
# 55658                     Noe     Manual            1587     5          4
#
#        empty_weight_kg Fuel_type                         fuel_consumption  \
# 14552              840  Gasoline   49l100kmcomb58l100kmcity44l100kmcoutry
# 25789             1350  Gasoline  75l100kmcomb103l100kmcity59l100kmcoutry
# 44337              875  Gasoline                              5l100kmcomb
# 55658              988  Gasoline                                      Noe
#
#       co2_emissions emission_class emissions_sticker  \
# 14552    115gkmcomb          Euro5              None
# 25789    180gkmcomb           None              None
# 44337    118gkmcomb           None              None
# 55658          None             nn              None
#
#                                    Comfort & Convenience  \
# 14552  'Air conditioning', 'Automatic climate control...
# 25789  'Air conditioning', 'Armrest', 'Automatic clim...
# 44337  'Air conditioning', 'Electrical side mirrors',...
# 55658  'Air conditioning', 'Automatic climate control...
#
#                                    Entertainment & Media  \
# 14552   'CD player', 'MP3', 'On-board computer', 'Radio'
# 25789          'CD player', 'On-board computer', 'Radio'
# 44337  'Bluetooth', 'CD player', 'Hands-free equipmen...
# 55658                               'CD player', 'Radio'
#
#                                        Safety & Security  \
# 14552  'ABS', 'Central door lock', 'Central door lock...
# 25789  'ABS', 'Central door lock', 'Central door lock...
# 44337  'ABS', 'Central door lock', 'Central door lock...
# 55658  'Central door lock', 'Central door lock with r...
#
#                                                   extras colour  \
# 14552                    'Alloy wheels (14")', 'Spoiler'  Black
# 25789                     'Sport seats', 'Trailer hitch'  Black
# 44337                                     'Alloy wheels'   None
# 55658  'Alloy wheels', 'Spare tyre', 'Sport package',...   Grey
#
#       manufacturer_color     paint upholstery_colour   upholstery  power_kw  \
# 14552               None  Metallic              None         None        51
# 25789               None  Metallic              Grey  Partleather       114
# 44337               None  Metallic              Grey        Cloth        51
# 55658               None  Metallic             Black        Cloth        80
#
#        power_hp
# 14552        69
# 25789       155
# 44337        69
# 55658       109

# %%
df.head(1)
# Out:
#      location  make model          short_description  price mileage_km  \
# 0  LOONOPZAND  Audi    A3  2.0 FSI Ambition Pro Line   4450     191066
#
#      gearbox registration fuel_type  seller body_type  type drivetrain seats  \
# 0  Automatic   2003-08-01  Gasoline  Dealer   Compact  Used      Front     5
#
#   doors country_version offer_number warranty_months first_registration  \
# 0     3            None       SJ112R               6         2003-08-01
#
#   production_date general_inspection last_service full_service_history  \
# 0             NaT         2022-05-01         None                  Yes
#
#   non_smoker_vehicle previous_owner last_timing_belt_change    Gearbox  \
# 0               None            Noe                     Noe  Automatic
#
#    engine_size_cc gears  cylinders  empty_weight_kg Fuel_type  \
# 0            1984  None          4             1280   Super95
#
#   fuel_consumption co2_emissions emission_class emissions_sticker  \
# 0              Noe            nn          Euro4              None
#
#                                Comfort & Convenience Entertainment & Media  \
# 0  'Air conditioning', 'Armrest', 'Automatic clim...  'CD player', 'Radio'
#
#                                    Safety & Security          extras colour  \
# 0  'ABS', 'Alarm system', 'Central door lock', 'C...  'Alloy wheels'   Grey
#
#   manufacturer_color     paint upholstery_colour upholstery  power_kw  \
# 0               None  Metallic             Black      Cloth       110
#
#    power_hp
# 0       150

# %%
plt.figure(figsize=(15, 10))
df.registration.dt.year.value_counts().plot.barh();

# %%
df.head(2)
# Out:
#      location  make model                                  short_description  \
# 0  LOONOPZAND  Audi    A3                          2.0 FSI Ambition Pro Line
# 1     HEERLEN  Audi    A3  Sportback 1.4 TFSI Ambiente/ECC/PDC//Lichtmeta...
#
#    price mileage_km    gearbox registration fuel_type  seller body_type  type  \
# 0   4450     191066  Automatic   2003-08-01  Gasoline  Dealer   Compact  Used
# 1  12950      94758  Automatic   2013-10-01  Gasoline  Dealer   Compact  Used
#
#   drivetrain seats doors country_version offer_number warranty_months  \
# 0      Front     5     3            None       SJ112R               6
# 1      Front     5     5            None       809725            None
#
#   first_registration production_date general_inspection last_service  \
# 0         2003-08-01             NaT         2022-05-01         None
# 1         2013-10-01             NaT                NaT         None
#
#   full_service_history non_smoker_vehicle previous_owner  \
# 0                  Yes               None            Noe
# 1                  Yes               None            Noe
#
#   last_timing_belt_change    Gearbox  engine_size_cc gears  cylinders  \
# 0                     Noe  Automatic            1984  None          4
# 1                     Noe  Automatic            1395  None          4
#
#    empty_weight_kg Fuel_type fuel_consumption co2_emissions emission_class  \
# 0             1280   Super95              Noe            nn          Euro4
# 1             1200  Gasoline     49l100kmcomb          None           None
#
#   emissions_sticker                              Comfort & Convenience  \
# 0              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 1              None  'Air conditioning', 'Automatic climate control...
#
#   Entertainment & Media                                  Safety & Security  \
# 0  'CD player', 'Radio'  'ABS', 'Alarm system', 'Central door lock', 'C...
# 1  'CD player', 'Radio'  'Alarm system', 'Central door lock', 'Central ...
#
#                  extras colour manufacturer_color     paint upholstery_colour  \
# 0        'Alloy wheels'   Grey               None  Metallic             Black
# 1  'Alloy wheels (16")'  White               None      None             Black
#
#   upholstery  power_kw  power_hp
# 0      Cloth       110       150
# 1      Cloth        92       125

# %%
df.make.value_counts(ascending=True)
# Out:
# Tesla            463
# Chevrolet        486
# Dacia            926
# Honda           1079
# Fiat            2148
# Mazda           2443
# Citroen         2460
# Hyundai         2582
# Opel            2642
# Kia             2854
# Skoda           2906
# Toyota          3146
# Peugeot         3976
# Ford            4544
# Renault         4826
# Volvo           5321
# Audi            6394
# MercedesBenz    6676
# Volkswagen      7359
# BMW             7873
# Name: make, dtype: int64

# %%
df.make.value_counts(ascending=True).index
# Out:
# Index(['Tesla', 'Chevrolet', 'Dacia', 'Honda', 'Fiat', 'Mazda', 'Citroen',
#        'Hyundai', 'Opel', 'Kia', 'Skoda', 'Toyota', 'Peugeot', 'Ford',
#        'Renault', 'Volvo', 'Audi', 'MercedesBenz', 'Volkswagen', 'BMW'],
#       dtype='object')

# %%
ç
sns.countplot(y = df.make, 
              order=ç,
             lw= 1, ec= 'black', hatch= '/')
plt.xlabel('Count of Cars')
plt.ylabel('Company')
plt.title('Car Compamies with Car')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x= df.make,
            y= df.price);

# %%
df.describe()
# Out:
#           price  engine_size_cc  cylinders  empty_weight_kg  power_kw  \
# count     69534           65265      64809            69500     65045
# mean      24369            1771          4             1433       116
# std      468620             702          1              321        59
# min           1               0          1                1         1
# 25%        8945            1390          4             1234        82
# 50%       17450            1598          4             1382       103
# 75%       28935            1995          4             1591       132
# max   123456789           65535         12             4200      3500
#
#        power_hp
# count     65041
# mean        157
# std          75
# min           1
# 25%         111
# 50%         140
# 75%         179
# max        2173

# %%
pd.set_option('display.max_rows', 30)
pd.options.display.float_format = '{:,.2f}'.format
df.groupby('make').price.describe()
# Out:
#                 count      mean          std       min       25%       50%  \
# make
# 14828  None       8.00         1,751.00  Gasoline
# 19883     9       8.00         2,020.00  Gasoline
# 20415     9       8.00         2,315.00  Gasoline
# 20417  None       8.00         2,460.00  Gasoline
# 20675     9       8.00         2,530.00   Super95
# 20677     9       8.00         2,530.00   Super95
# 20687     9       8.00         2,530.00   Super95
# 21805     7       8.00         1,635.00   Super95
# 22706     5       8.00         2,420.00    Diesel
# 23072     5       8.00         2,420.00    Diesel
# 66537  None       5.00         1,574.00       LPG
# 71027  None       5.00         1,574.00       LPG
#
#                                fuel_consumption co2_emissions emission_class  \
# 1243                              129l100kmcomb      0gkmcomb           None
# 1245                              131l100kmcomb    296gkmcomb     Euro6dTEMP
# 1336                                        Noe          None           None
# 1406     77l100kmcomb107l100kmcity6l100kmcoutry    183gkmcomb          Euro4
# 1916                              137l100kmcomb    300gkmcomb     Euro6dTEMP
# 1923                              137l100kmcomb    300gkmcomb     Euro6dTEMP
# 1927                              137l100kmcomb      0gkmcomb           None
# 2410                              115l100kmcomb          None           None
# 7412                                        Noe            nn           None
# 7413                                        Noe            nn          Euro3
# 8520                                        Noe            nn           None
# 8523                              126l100kmcomb      0gkmcomb           None
# 14828                             126l100kmcomb          None           None
# 19883                             132l100kmcomb    299gkmcomb          Euro6
# 20415                                       Noe          None           None
# 20417                             164l100kmcomb          None           None
# 20675                             127l100kmcomb      0gkmcomb           None
# 20677                             127l100kmcomb      0gkmcomb           None
# 20687  12l100kmcomb154l100kmcity101l100kmcoutry    275gkmcomb          Euro6
# 21805                             125l100kmcomb    284gkmcomb          Euro6
# 22706                                       Noe            nn           None
# 23072                                       Noe            nn           None
# 66537   106l100kmcomb15l100kmcity81l100kmcoutry    252gkmcomb          Euro3
# 71027   106l100kmcomb15l100kmcity81l100kmcoutry    252gkmcomb          Euro3
#
#       emissions_sticker                              Comfort & Convenience  \
# 1243               None  'Air conditioning', 'Automatic climate control...
# 1245               None  'Air conditioning', 'Automatic climate control...
# 1336               None  'Air conditioning', 'Armrest', 'Automatic clim...
# 1406               None  'Air conditioning', 'Automatic climate control...
# 1916               None  'Air conditioning', 'Air suspension', 'Armrest...
# 1923               None  'Air conditioning', 'Air suspension', 'Armrest...
# 1927               None  'Air conditioning', 'Air suspension', 'Auxilia...
# 2410               None  'Air conditioning', 'Air suspension', 'Armrest...
# 7412               None  'Air conditioning', 'Cruise control', 'Electri...
# 7413               None  'Air conditioning', 'Cruise control', 'Electri...
# 8520               None  'Auxiliary heating', 'Electrically adjustable ...
# 8523               None  'Air conditioning', 'Air suspension', 'Armrest...
# 14828              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 19883              None  '360° camera', 'Air conditioning', 'Armrest', ...
# 20415              None  '360° camera', 'Air conditioning', 'Automatic ...
# 20417              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 20675              None  'Air conditioning', 'Air suspension', 'Armrest...
# 20677              None  'Air conditioning', 'Air suspension', 'Armrest...
# 20687              None  '360° camera', 'Air conditioning', 'Air suspen...
# 21805              None  'Air conditioning', 'Automatic climate control...
# 22706              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 23072              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 66537              None  'Air conditioning', 'Armrest', 'Automatic clim...
# 71027              None  'Air conditioning', 'Armrest', 'Automatic clim...
#
#                                    Entertainment & Media  \
# 1243   'Android Auto', 'Apple CarPlay', 'Digital cock...
# 1245   'Digital cockpit', 'Digital radio', 'Hands-fre...
# 1336   'CD player', 'Digital radio', 'On-board comput...
# 1406                         'Bluetooth', 'Sound system'
# 1916   'Digital cockpit', 'Digital radio', 'Hands-fre...
# 1923   'Digital cockpit', 'Digital radio', 'Hands-fre...
# 1927   'Digital cockpit', 'Digital radio', 'Hands-fre...
# 2410   'Digital cockpit', 'Digital radio', 'Hands-fre...
# 7412                                             'Radio'
# 7413                                'CD player', 'Radio'
# 8520                  'Digital cockpit', 'Digital radio'
# 8523   'Android Auto', 'Apple CarPlay', 'Digital cock...
# 14828  'Android Auto', 'Apple CarPlay', 'Digital cock...
# 19883  'Apple CarPlay', 'Digital radio', 'On-board co...
# 20415  'Android Auto', 'Apple CarPlay', 'Digital radi...
# 20417  'Android Auto', 'Apple CarPlay', 'Digital cock...
# 20675  'Android Auto', 'Apple CarPlay', 'Digital cock...
# 20677  'Android Auto', 'Apple CarPlay', 'Digital cock...
# 20687  'Android Auto', 'Apple CarPlay', 'Digital cock...
# 21805  'Apple CarPlay', 'Digital radio', 'Hands-free ...
# 22706  'Bluetooth', 'Hands-free equipment', 'Radio', ...
# 23072  'Bluetooth', 'Hands-free equipment', 'Radio', ...
# 66537          'CD player', 'On-board computer', 'Radio'
# 71027          'CD player', 'On-board computer', 'Radio'
#
#                                        Safety & Security  \
# 1243   'ABS', 'Alarm system', 'Central door lock', 'C...
# 1245   'ABS', 'Alarm system', 'Central door lock', 'C...
# 1336   'ABS', 'Alarm system', 'Central door lock', 'C...
# 1406   'ABS', 'Adaptive Cruise Control', 'Alarm syste...
# 1916   'ABS', 'Adaptive Cruise Control', 'Adaptive he...
# 1923   'ABS', 'Adaptive Cruise Control', 'Adaptive he...
# 1927   'Adaptive Cruise Control', 'Blind spot monitor...
# 2410   'ABS', 'Alarm system', 'Central door lock', 'C...
# 7412   'ABS', 'Alarm system', 'Central door lock', 'C...
# 7413   'ABS', 'Alarm system', 'Central door lock', 'C...
# 8520   'Alarm system', 'Driver drowsiness detection',...
# 8523   'ABS', 'Adaptive Cruise Control', 'Adaptive he...
# 14828  'ABS', 'Daytime running lights', 'Driver-side ...
# 19883  'Central door lock', 'Central door lock with r...
# 20415  'ABS', 'Driver-side airbag', 'Emergency system...
# 20417  'ABS', 'Adaptive Cruise Control', 'Adaptive he...
# 20675  'ABS', 'Adaptive Cruise Control', 'Adaptive he...
# 20677  'ABS', 'Adaptive headlights', 'Alarm system', ...
# 20687  'ABS', 'Adaptive Cruise Control', 'Adaptive he...
# 21805  'Alarm system', 'Blind spot monitor', 'Emergen...
# 22706  'ABS', 'Alarm system', 'Central door lock', 'C...
# 23072  'ABS', 'Alarm system', 'Central door lock', 'C...
# 66537  'ABS', 'Alarm system', 'Central door lock', 'C...
# 71027  'ABS', 'Alarm system', 'Central door lock', 'C...
#
#                                                   extras  colour  \
# 1243   'Alloy wheels (20")', 'Shift paddles', 'Spoile...   Black
# 1245   'Alloy wheels (20")', 'Shift paddles', 'Spoile...   Green
# 1336             'Automatically dimming interior mirror'   White
# 1406              'Alloy wheels', 'Spoiler', 'Tuned car'     Red
# 1916   'Alloy wheels', 'Automatically dimming interio...    Grey
# 1923   'Alloy wheels', 'Automatically dimming interio...   Black
# 1927   'Automatically dimming interior mirror', 'Spor...    Blue
# 2410   'Alloy wheels (21")', 'Automatically dimming i...    None
# 7412            'Headlight washer system', 'Sport seats'  Silver
# 7413                                       'Sport seats'    Grey
# 8520                    'Shift paddles', 'Trailer hitch'    Grey
# 8523   'Automatically dimming interior mirror', 'Emer...    Grey
# 14828  'Alloy wheels (20")', 'Automatically dimming i...    Grey
# 19883  'Alloy wheels', 'Ambient lighting', 'Sport pac...    Grey
# 20415  'Alloy wheels', 'Ambient lighting', 'Trailer h...   Black
# 20417  'Alloy wheels (20")', 'Automatically dimming i...   Black
# 20675  'Alloy wheels (21")', 'Automatically dimming i...   Black
# 20677  'Alloy wheels (21")', 'Automatically dimming i...    Grey
# 20687  'Alloy wheels (21")', 'Automatically dimming i...   Black
# 21805                  'Ambient lighting', 'Sport seats'    Grey
# 22706  'Alloy wheels (18")', 'Automatically dimming i...    Blue
# 23072  'Alloy wheels (18")', 'Automatically dimming i...    Blue
# 66537              'Alloy wheels (16")', 'Trailer hitch'    Blue
# 71027              'Alloy wheels (16")', 'Trailer hitch'    Blue
#
#       manufacturer_color     paint upholstery_colour   upholstery  power_kw  \
# 1243                None  Metallic             Black  Fullleather    456.00
# 1245                None      None             Black  Fullleather    456.00
# 1336                None  Metallic             Black  Fullleather    449.00
# 1406                None      None              None         None    210.00
# 1916                None  Metallic             Black  Partleather    441.00
# 1923                None  Metallic             Black  Partleather    441.00
# 1927                None  Metallic             Black  Fullleather    441.00
# 2410                None      None              None  Partleather    441.00
# 7412                None  Metallic               Red  Fullleather    294.00
# 7413                None  Metallic               Red  Fullleather    294.00
# 8520                None  Metallic             Black         None       NaN
# 8523                None  Metallic             Black  Fullleather    457.00
# 14828               None  Metallic              None    alcantara    559.00
# 19883               None      None             Black  Fullleather    470.00
# 20415               None  Metallic             Black  Fullleather    450.00
# 20417               None  Metallic              None  Fullleather    430.00
# 20675               None  Metallic             Black  Fullleather    450.00
# 20677               None  Metallic             Black  Fullleather    450.00
# 20687               None  Metallic             Black  Fullleather    450.00
# 21805               None      None             Black  Fullleather    430.00
# 22706               None  Metallic             Black  Fullleather    184.00
# 23072               None  Metallic             Black  Fullleather    184.00
# 66537               None  Metallic              None  Fullleather    142.00
# 71027               None  Metallic              None  Fullleather    142.00
#
#        power_hp
# 1243     620.00
# 1245     620.00
# 1336     610.00
# 1406     286.00
# 1916     600.00
# 1923     600.00
# 1927     600.00
# 2410     600.00
# 7412     400.00
# 7413     400.00
# 8520        NaN
# 8523     621.00
# 14828    760.00
# 19883    639.00
# 20415    612.00
# 20417    585.00
# 20675    612.00
# 20677    612.00
# 20687    612.00
# 21805    585.00
# 22706    250.00
# 23072    250.00
# 66537    193.00
# 71027    193.00
