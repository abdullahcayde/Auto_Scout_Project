# %%
# ------------------------------ Time Series --------------------------------
# Read csv parse_dates
d_parser = lambda x : pd.datetime.strptime(x, '%m/%Y')
df = pd.read_csv('/data.csv', parse_dates=['production_date'], date_parser=d_parser)
df.head()

# to_datetime
L05 = ['registration', 'first_registration', 'general_inspection']
for i in L05:
    df_dates[i] = pd.to_datetime(df_dates[i], format= '%m/%Y', errors= 'coerce')

# Column Reg, first index , find day name 
df_dates.loc[1, 'registration'].day_name()
# Column select year
df_dates.first_registration.dt.year
    
# Make new column as a DAY (Friday, .....)
df_dates['new_column'] = df_dates['registration'].dt.day_name()

# Max and Min Dates
df['Date'].min()
df['Date'].max()

# TimeDelta
df['Date'].max() - df['Date'].min()

# Date Filter
filt = (df['date'] >= '2019') & (df['date'] < '2022')
df.loc[filt]

filt = (df['date'] >= pd.to_datetime('2019-01-01')) & (df['date'] < pd.to_datetime('2022-03-01')
df.loc(filt)

# set as index
df.set_index('date', inplace= True)

# after 
df['2019']
df['2020-01' : '2020-02']
df['2020-01' : '2020-02']['column'].mean()
                                                       
# strftime
a = df_dates.loc[1, 'registration'].strftime('%m/%Y')
print(type(a))
a  ====> # Output : class 'str' , '08/2021'

--------------------------------------
# resample 
#index date yapildi
highs = df['column'].resample('D').max()
                                                       
# Matplotlib install
# %matplotlib inline
highs.plot();

# weekly see columns min max sum
df.resample('W').agg({'column': 'mean',
                     'column2': 'max',
                     'column3': 'sum',
                     'column4': 'min'})
----------------------------------------
                                                       
                                                       
                                                       
                                                       
                                                       
                                                       
                                                       
                                                       
                                                       
---------------------------------------------

# Column Reg, first index , find day name 
df_dates.loc[1, 'registration'].day_name()

# split expand
L04 = ['power_kw', 'power_hp']
df[L04] = df.power.str.split('kW', expand= True) 

# replace
df['power_hp'] = df['power_hp'].str.replace('hp', '').replace('None', np.NaN)

# regex clean unwanted Chracters
for column in clmns:
    df[column] = df[column].str.replace(r'\W', '')

# %%
#--------------------------- Matplotlib ------------------------
#https://matplotlib.org/3.1.1/gallery/index.html
#https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py
import numpy as np
import matplotlib.pyplot as plt


x = [1, 2 ,3 ,4 , 5 ]
y1 = np.random.randint(0,100,5)
y2 = np.random.randint(0,100,5)

plt.plot(x, y1, label= 'Y1')
plt.plot(x, y2, label= 'Y2')

plt.xlabel('')
plt.ylabel('')

plt.legend()

plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
import numpy as np
import matplotlib.pyplot as plt

#print(plt.style.available)
plt.style.use('seaborn')

x = [1, 2 ,3 ,4 , 5 ]
y1 = np.random.randint(0,100,5)
y2 = np.random.randint(0,100,5)
y3 = np.random.randint(0,100,5)

plt.plot(x, y1, color= 'r', linestyle='-', marker='o', linewidth= 5,label= 'Y1')
plt.plot(x, y2, 'b-o',label= 'Y2')

plt.xlabel('')
plt.ylabel('')

plt.grid(True)

plt.legend()

plt.tight_layout()

#save
plt.savefig('fig_name01.png')

plt.show()

# %%
#--- Countplot order = 


plt.figure(figsize = (15,10))
sns.countplot(y = df.make, order=df.make.value_counts(ascending=True).index )
plt.xlabel('Count of Cars')
plt.ylabel('Company')
plt.title('Car Compamies with Car')
plt.show()
